# %%
import pm4py
import json
import pandas as pd

# %%
bp_ex = pm4py.read_bpmn("running_example_annotated.bpmn")

# %%
log = pm4py.read_xes('running-example.xes', return_legacy_log_object=False)
# Out:
# parsing log, completed traces ::   0%|          | 0/6 [00:00<?, ?it/s]

# %%
type(log)
# Out:
# pandas.core.frame.DataFrame

# %%
vars = pm4py.statistics.variants.log.get.get_variants(log)

# %%
vars
# Out:
# {('register request',
#   'examine thoroughly',
#   'check ticket',
#   'decide',
#   'reject request'): [{'attributes': {'concept:name': '1'}, 'events': [{'concept:name': 'register request', 'time:timestamp': Timestamp('2010-12-30 10:02:00+0000', tz='UTC'), 'cost:total': 50, 'org:resource': 'Pete', '@@index': 14}, '..', {'concept:name': 'reject request', 'time:timestamp': Timestamp('2011-01-07 13:24:00+0000', tz='UTC'), 'cost:total': 200, 'org:resource': 'Pete', '@@index': 18}]}],
#  ('register request',
#   'check ticket',
#   'examine casually',
#   'decide',
#   'pay compensation'): [{'attributes': {'concept:name': '2'}, 'events': [{'concept:name': 'register request', 'time:timestamp': Timestamp('2010-12-30 10:32:00+0000', tz='UTC'), 'cost:total': 50, 'org:resource': 'Mike', '@@index': 9}, '..', {'concept:name': 'pay compensation', 'time:timestamp': Timestamp('2011-01-08 11:05:00+0000', tz='UTC'), 'cost:total': 200, 'org:resource': 'Ellen', '@@index': 13}]}],
# ...

# %%
list(vars)[0]
# Out:
# ('register request',
#  'examine thoroughly',
#  'check ticket',
#  'decide',
#  'reject request')

# %%
log1 = pm4py.filtering.filter_event_attribute_values(log, 'concept:name', {'examine thoroughly'})

# %%
log
# Out:
#           concept:name            time:timestamp  cost:total org:resource  \
# 0     register request 2010-12-30 10:02:00+00:00          50         Pete
# 1   examine thoroughly 2010-12-31 09:06:00+00:00         400          Sue
# 2         check ticket 2011-01-05 14:12:00+00:00         100         Mike
# 3               decide 2011-01-06 10:18:00+00:00         200         Sara
# 4       reject request 2011-01-07 13:24:00+00:00         200         Pete
# 5     register request 2010-12-30 10:32:00+00:00          50         Mike
# 6         check ticket 2010-12-30 11:12:00+00:00         100         Mike
# 7     examine casually 2010-12-30 13:16:00+00:00         400         Sean
# 8               decide 2011-01-05 10:22:00+00:00         200         Sara
# 9     pay compensation 2011-01-08 11:05:00+00:00         200        Ellen
# 10    register request 2010-12-30 13:32:00+00:00          50         Pete
# 11    examine casually 2010-12-30 14:06:00+00:00         400         Mike
# ...

# %%
log1
# Out:
#           concept:name            time:timestamp  cost:total org:resource  \
# 0     register request 2010-12-30 10:02:00+00:00          50         Pete
# 1   examine thoroughly 2010-12-31 09:06:00+00:00         400          Sue
# 2         check ticket 2011-01-05 14:12:00+00:00         100         Mike
# 3               decide 2011-01-06 10:18:00+00:00         200         Sara
# 4       reject request 2011-01-07 13:24:00+00:00         200         Pete
# 10    register request 2010-12-30 13:32:00+00:00          50         Pete
# 11    examine casually 2010-12-30 14:06:00+00:00         400         Mike
# 12        check ticket 2010-12-30 15:34:00+00:00         100        Ellen
# 13              decide 2011-01-06 08:18:00+00:00         200         Sara
# 14  reinitiate request 2011-01-06 11:18:00+00:00         200         Sara
# 15  examine thoroughly 2011-01-06 12:06:00+00:00         400         Sean
# 16        check ticket 2011-01-08 10:43:00+00:00         100         Pete
# ...

# %%
log2 = pm4py.filtering.filter_event_attribute_values(log, 'concept:name', {'examine thoroughly'}, retain=False)

# %%
log2
# Out:
#           concept:name            time:timestamp  cost:total org:resource  \
# 5     register request 2010-12-30 10:32:00+00:00          50         Mike
# 6         check ticket 2010-12-30 11:12:00+00:00         100         Mike
# 7     examine casually 2010-12-30 13:16:00+00:00         400         Sean
# 8               decide 2011-01-05 10:22:00+00:00         200         Sara
# 9     pay compensation 2011-01-08 11:05:00+00:00         200        Ellen
# 24    register request 2011-01-06 08:02:00+00:00          50        Ellen
# 25    examine casually 2011-01-07 09:16:00+00:00         400         Mike
# 26        check ticket 2011-01-08 10:22:00+00:00         100         Pete
# 27              decide 2011-01-10 12:28:00+00:00         200         Sara
# 28  reinitiate request 2011-01-11 15:18:00+00:00         200         Sara
# 29        check ticket 2011-01-14 13:33:00+00:00         100        Ellen
# 30    examine casually 2011-01-16 14:50:00+00:00         400         Mike
# ...

# %%
pm4py.write_xes(log1, 'log1.xes')
# Out:
# exporting log, completed traces ::   0%|          | 0/3 [00:00<?, ?it/s]

# %%
pm4py.write_xes(log2, 'log2.xes')
# Out:
# exporting log, completed traces ::   0%|          | 0/3 [00:00<?, ?it/s]
